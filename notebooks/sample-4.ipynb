# %%
import mne
raw = mne.io.read_raw_edf("sample_eeg.edf", preload=True)
print(raw)
# Out:
# Extracting EDF parameters from sample_eeg.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# <RawEDF | sample_eeg.edf, 64 x 9760 (61.0 s), ~4.8 MiB, data loaded>

# %%
raw = mne.io.read_raw_edf("sample_eeg.edf", preload=True)
# Out:
# Extracting EDF parameters from sample_eeg.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...

# %%
raw.rename_channels(lambda s: s.strip().replace(".", ""))
raw.set_montage("standard_1020", on_missing="ignore")
rename_dict = { "Fc5": "FC5", "Fc3": "FC3", "Fc1": "FC1", "Fcz": "FCz", "Fc2": "FC2", "Fc4": "FC4", "Fc6": "FC6", "Cp5": "CP5", "Cp3": "CP3", "Cp1": "CP1", "Cpz": "CPz", "Cp2": "CP2", "Cp4": "CP4", "Cp6": "CP6", "Af7": "AF7", "Af3": "AF3", "Afz": "AFz", "Af4": "AF4", "Af8": "AF8", "Ft7": "FT7", "Ft8": "FT8", "Tp7": "TP7", "Tp8": "TP8", "Po7": "PO7", "Po3": "PO3", "Poz": "POz", "Po4": "PO4", "Po8": "PO8", }

raw.rename_channels(rename_dict) 
raw_eeg = raw.copy().pick("eeg") 
raw_eeg.set_montage("standard_1020", on_missing="raise") 
raw_eeg.plot_sensors(show_names=True)
montage = mne.channels.make_standard_montage("standard_1020")
print(montage.ch_names)
# Out:
# ['Fp1', 'Fpz', 'Fp2', 'AF9', 'AF7', 'AF5', 'AF3', 'AF1', 'AFz', 'AF2', 'AF4', 'AF6', 'AF8', 'AF10', 'F9', 'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'F10', 'FT9', 'FT7', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'FT8', 'FT10', 'T9', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'T10', 'TP9', 'TP7', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'TP8', 'TP10', 'P9', 'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO9', 'PO7', 'PO5', 'PO3', 'PO1', 'POz', 'PO2', 'PO4', 'PO6', 'PO8', 'PO10', 'O1', 'Oz', 'O2', 'O9', 'Iz', 'O10', 'T3', 'T5', 'T4', 'T6', 'M1', 'M2', 'A1', 'A2']

# %%
raw.rename_channels(lambda s: s.strip().replace(".", ""))
# Out:
# <RawEDF | sample_eeg.edf, 64 x 9760 (61.0 s), ~4.8 MiB, data loaded>

# %%
print(raw.ch_names)
# Out:
# ['FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'Fp1', 'Fpz', 'Fp2', 'AF7', 'AF3', 'AFz', 'AF4', 'AF8', 'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT7', 'FT8', 'T7', 'T8', 'T9', 'T10', 'TP7', 'TP8', 'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO3', 'POz', 'PO4', 'PO8', 'O1', 'Oz', 'O2', 'Iz']

# %%
montage = mne.channels.make_standard_montage("standard_1020")
print(montage.ch_names)
# Out:
# ['Fp1', 'Fpz', 'Fp2', 'AF9', 'AF7', 'AF5', 'AF3', 'AF1', 'AFz', 'AF2', 'AF4', 'AF6', 'AF8', 'AF10', 'F9', 'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'F10', 'FT9', 'FT7', 'FC5', 'FC3', 'FC1', 'FCz', 'FC2', 'FC4', 'FC6', 'FT8', 'FT10', 'T9', 'T7', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'T8', 'T10', 'TP9', 'TP7', 'CP5', 'CP3', 'CP1', 'CPz', 'CP2', 'CP4', 'CP6', 'TP8', 'TP10', 'P9', 'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO9', 'PO7', 'PO5', 'PO3', 'PO1', 'POz', 'PO2', 'PO4', 'PO6', 'PO8', 'PO10', 'O1', 'Oz', 'O2', 'O9', 'Iz', 'O10', 'T3', 'T5', 'T4', 'T6', 'M1', 'M2', 'A1', 'A2']

# %%
raw_eeg.compute_psd().plot()
# Out:
# Effective window size : 12.800 (s)
# Plotting power spectral density (dB=True).
# C:\Users\alexb\.conda\envs\eeg\Lib\site-packages\mne\viz\utils.py:160: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 2 Axes>
# <MNELineFigure size 1000x350 with 2 Axes>
