# %%
import mne
raw = mne.io.read_raw_edf("sample_eeg.edf", preload=True)
print(raw)
# Out:
# Extracting EDF parameters from sample_eeg.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...
# <RawEDF | sample_eeg.edf, 64 x 9760 (61.0 s), ~4.8 MiB, data loaded>

# %%
raw = mne.io.read_raw_edf("sample_eeg.edf", preload=True)
# Out:
# Extracting EDF parameters from sample_eeg.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...

# %%
raw.rename_channels(lambda s: s.strip().replace(".", ""))
raw.set_montage("standard_1020", on_missing="ignore")
rename_dict = { "Fc5": "FC5", "Fc3": "FC3", "Fc1": "FC1", "Fcz": "FCz", "Fc2": "FC2", "Fc4": "FC4", "Fc6": "FC6", "Cp5": "CP5", "Cp3": "CP3", "Cp1": "CP1", "Cpz": "CPz", "Cp2": "CP2", "Cp4": "CP4", "Cp6": "CP6", "Af7": "AF7", "Af3": "AF3", "Afz": "AFz", "Af4": "AF4", "Af8": "AF8", "Ft7": "FT7", "Ft8": "FT8", "Tp7": "TP7", "Tp8": "TP8", "Po7": "PO7", "Po3": "PO3", "Poz": "POz", "Po4": "PO4", "Po8": "PO8", }

raw.rename_channels(rename_dict) 
raw_eeg = raw.copy().pick("eeg") 
raw_eeg.set_montage("standard_1020", on_missing="raise") 
raw_eeg.plot_sensors(show_names=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 raw.set_montage("standard_1020", on_missing="ignore")
#       2 rename_dict = { "Fc5": "FC5", "Fc3": "FC3", "Fc1": "FC1", "Fcz": "FCz", "Fc2": "FC2", "Fc4": "FC4", "Fc6": "FC6", "Cp5": "CP5", "Cp3": "CP3", "Cp1": "CP1", "Cpz": "CPz", "Cp2": "CP2", "Cp4": "CP4", "Cp6": "CP6", "Af7": "AF7", "Af3": "AF3", "Afz": "AFz", "Af4": "AF4", "Af8": "AF8", "Ft7": "FT7", "Ft8": "FT8", "Tp7": "TP7", "Tp8": "TP8", "Po7": "PO7", "Po3": "PO3", "Poz": "POz", "Po4": "PO4", "Po8": "PO8", }
# ----> 4 raw.rename_channels(rename_dict)
#       5 raw_eeg = raw.copy().pick("eeg")
#       6 raw_eeg.set_montage("standard_1020", on_missing="raise")
#
# File <decorator-gen-24>:12, in rename_channels(self, mapping, allow_duplicates, on_missing, verbose)
#
# File ~\.conda\envs\eeg\Lib\site-packages\mne\_fiff\meas_info.py:661, in SetChannelsMixin.rename_channels(self, mapping, allow_duplicates, on_missing, verbose)
#     658 info = self if isinstance(self, Info) else self.info
#     660 ch_names_orig = list(info["ch_names"])
# --> 661 rename_channels(info, mapping, allow_duplicates, on_missing=on_missing)
#     663 # Update self._orig_units for Raw
#     664 if isinstance(self, BaseRaw):
#     665     # whatever mapping was provided, now we can just use a dict
#
# File <decorator-gen-135>:12, in rename_channels(info, mapping, allow_duplicates, on_missing, verbose)
#
# File ~\.conda\envs\eeg\Lib\site-packages\mne\channels\channels.py:1171, in rename_channels(info, mapping, allow_duplicates, on_missing, verbose)
#    1165     if new_mapping != mapping and on_missing == "warn":
#    1166         warn(
#    1167             "Channel rename map contains keys that are not present in the object "
#    1168             "to be renamed. These will be ignored."
#    1169         )
# -> 1171     _check_dict_keys(
#    1172         new_mapping,
#    1173         ch_names,
#    1174         key_description="channel name(s)",
#    1175         valid_key_source="info",
#    1176     )
#    1177     new_names = [
#    1178         (ch_names.index(ch_name), new_name)
#    1179         for ch_name, new_name in new_mapping.items()
#    1180     ]
#    1181 elif callable(mapping):
#
# File ~\.conda\envs\eeg\Lib\site-packages\mne\utils\check.py:883, in _check_dict_keys(mapping, valid_keys, key_description, valid_key_source)
#     878     _is = "are" if len(missing) > 1 else "is"
#     879     msg = (
#     880         f"Invalid {key_description} {missing} {_is} not present in "
#     881         f"{valid_key_source}"
#     882     )
# --> 883     raise ValueError(msg)
#     885 return mapping
#
# ValueError: Invalid channel name(s) {'Fcz', 'Po4', 'Fc2', 'Tp8', 'Af4', 'Ft8', 'Cp6', 'Tp7', 'Cp2', 'Fc4', 'Af7', 'Cp3', 'Poz', 'Af3', 'Cp4', 'Af8', 'Fc1', 'Po3', 'Cp5', 'Cp1', 'Fc3', 'Fc5', 'Cpz', 'Po8', 'Fc6', 'Afz', 'Ft7', 'Po7'} are not present in info

# %%
raw.rename_channels(lambda s: s.strip().replace(".", ""))

# %%
print(raw.ch_names)

# %%
montage = mne.channels.make_standard_montage("standard_1020")
print(montage.ch_names)
